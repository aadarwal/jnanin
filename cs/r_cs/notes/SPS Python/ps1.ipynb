# %% [markdown]
# # 'Python for Research' Program Practice Problems 1
#
# **Written By: Joseph Yeung**

# %% [markdown]
# *Note, please do not distribute any of these materials without expressed consent from Joseph Yeung!*

# %% [markdown]
# These problems are meant to accompany lecture 1. These problems are **not** at all mandatory. Treat them as additional practice to familiarize yourself with the tools discussed in lecture, if and only if you have the time to do them. I don't anticipate any of these problems to take too long.

# %% [markdown]
# ## 1. Winter Quarter Classes
#
# **a.** Create a dictionary with your classes this quarter. The dictionary should have the class name as the key and information about the time stored in each key. Anything else you want to add in this dictionary is up to you. Think about the data type(s) you will use.

# %% [markdown]
# **b.** Practice the following
#
# - Retrieving dictionary data associated with each key.
# - Print the keys of the dictionary
# - Add an additional key with these Python Lectures!

# %% [markdown]
# ## 2. Simple Physics Calculations
#
# The worst part of any physics problem (in my opinion) is plugging in numbers at the end. While Python doesn't make it any more fun, it can at least make certain things more efficient. Compute the following, and think about how you can use variable assignment to make the process more efficient.
#
# - Calculate the Gravitational Force between the Sun and Earth.
# - Calculate the Gravitational Force between the Moon and Earth.
# - Calculate the fraction of these two values.
# - Calculate the average of these two values
#
# Feel free to look up values and constants, and please use appropriate print statements to make your answers clear. Bonus points for being able to print units too! For reference,
#
# \begin{equation}
# F = G\frac{m_1m_2}{r^2}
# \end{equation}

# %% [markdown]
# ## 3. Fibonacci Sequence and Lists

# %% [markdown]
# The following are the first couple of terms of the Fibonacci sequence (if you don't know what this is, look it up! It's pretty cool).

# %%
fib = [0, 1, 1, 2, 3, 5, 8, 13, 22, 34]

# %% [markdown]
# **a.** Turns out there is a mistake! Catch the mistake, then use indexing and reassignment to fix it.

# %% [markdown]
# **b.** Append the next term in the sequence to the list. Please use list indexing and the definition of the Fibonacci sequence to perform the calculation; do not just look up the next term! Index this final term and print it.

# %% [markdown]
# **c.** Of these terms, compute the average of the terms. Hint: with the appropriate tools, you should be able to do this in one line of code.

# %% [markdown]
# ## 4. Indexing Strings

# %% [markdown]
# **a.** Assign a variable to be a string that is your full name.

# %% [markdown]
# **b.** What happens when you try to index this string variable? Aka, perform x[i] for some i on your variable.

# %% [markdown]
# **c.** Print the datatype of both the full string and the index of the string.

# %% [markdown]
# # 'Python for Research' Program Practice Problems 2
#
# **Written By: Joseph Yeung**

# %% [markdown]
# *Note, please do not distribute any of these materials without expressed consent from Joseph Yeung!*

# %% [markdown]
# These problems are meant to accompany lecture 2. These problems are **not** at all mandatory. Treat them as additional practice to familiarize yourself with the tools discussed in lecture, if and only if you have the time to do them. I don't anticipate any of these problems to take too long.

# %% [markdown]
# ## 1. Electric Fields and Forces as Functions

# %% [markdown]
# **a.** Create a function that, given a charge and distance, can calculate the (scalar) Electric Field produced by the charge. Recall,
#
# \begin{equation}
# E = \frac{1}{4 \pi \epsilon_0}\frac{q}{r^2}
# \end{equation}
#
# Feel free to look up values.

# %% [markdown]
# **b.** Now, create a new function that - given a test charge, field charge, and distance between the two - can calculate the force between the two charges. This function should call the previous function you just created! Recall,
#
# \begin{equation}
# F = qE
# \end{equation}

# %% [markdown]
# **c.** Finally, calculate the force between a proton and electron seperated by a distance of one Bohr radius. Once again, feel free to look up values.

# %% [markdown]
# In the semi-classical Bohr model of the Hydrogen atom, this is the force that an electron would feel at its lowest allowed energy level. Ignore this if this means nothing to you.

# %% [markdown]
# ## 2. List Element Identification Function

# %% [markdown]
# **a.** Create a function that takes in a list and some x as its inputs. Create a function that can confirm or deny whether x is an element of the list. If it is, have the function return the index of the element. Think about how you may deal with the case of if x is in the list multiple times. Any answer is a good one, so long as you think it through and make it logical.
#
# Note: With many problems in coding, there are millions of ways to get it to work. Do try to think a little about how to make the process efficient, but at the end of the day if it works, it works (at least to a physicist; don't ask a CS major about this...).

# %% [markdown]
# **b.** Test it with the following list and x's.

# %%
test_list = [1, 4, 5, 7, 2, 7, 4]
x1 = 3
x2 = 2
x3 = 4

# %% [markdown]
# ## 3. Divisors

# %% [markdown]
# Remember that a number $m$ is said to be a divisor of another number $n$ if their quotient $n/m$ is an integer. For example, $5$ is a divisor of $45$ but $11$ most definitely isn't.
#
# Create a function that, given some integer, can compute and return all of its divisors. Only consider positive numbers. Test it by calculating the divisors of $13$, $64$, and $100$.
#
# Hint: Like the prime number example in lecture, think methodically about how you can test whether division produces an integer or not. performing $45/5$ in Python will produce $9.0$. While we know this is an integer, Python sees this as a float, so the simple type() function won't be sufficient!
